# %%
import pandas as pd

df_marzo_25 = pd.read_csv("marzo_2025.csv", sep=";", encoding="utf-8")

# %%
columnas_keep = [
    "ESTUDIO Código del estudio",
    "REGISTRO Número de registro",
    "CCAA Comunidad autónoma",
    "TAMUNI Tamaño de municipio",
    "SEXO Sexo de la persona entrevistada",
    "EDAD Edad de la persona entrevistada",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)",
    "RELIGION Religiosidad de la persona entrevistada",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos",
    "ESTUDIOS Estudios de la persona entrevistada",
    "SITLAB Situación laboral de la persona entrevistada",
    "INGRESHOG Nivel de ingresos netos del hogar",
    "CLASESUB Identificación subjetiva de clase",
    "IA_E1_MES Mes de realización",
    "IA_E1_ANYO Año de realización",
    "PESO Ponderación con ajuste por Estudios",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023",
    "CERCANIA Partido político que considera más cercano a sus ideas",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]",

    "PESPANNA1 Primer problema",
    "PESPANNA2 Segundo problema",
    "PESPANNA3 Tercer problema"
]

df_marzo_25 = df_marzo_25[columnas_keep].copy()

# %%
# Renombrar columnas a nombres más cómodos
df_marzo_25 = df_marzo_25.rename(columns={
    "ESTUDIO Código del estudio": "Mes/Año",
    "REGISTRO Número de registro": "Id",
    "CCAA Comunidad autónoma": "CCAA",
    "TAMUNI Tamaño de municipio": "Poblacion_municipio",
    "SEXO Sexo de la persona entrevistada": "Sexo",
    "EDAD Edad de la persona entrevistada": "Edad",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)": "Ideologia",
    "RELIGION Religiosidad de la persona entrevistada": "Religiosidad",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos": "Practica_religion",
    "ESTUDIOS Estudios de la persona entrevistada": "Estudios",
    "SITLAB Situación laboral de la persona entrevistada": "Situacion_laboral",
    "INGRESHOG Nivel de ingresos netos del hogar": "Ingresos_hogar",
    "CLASESUB Identificación subjetiva de clase": "Clase_social",
    "IA_E1_MES Mes de realización": "Mes",
    "IA_E1_ANYO Año de realización": "Año",
    "PESO Ponderación con ajuste por Estudios": "Peso",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023": "Participacion_2023",
    "CERCANIA Partido político que considera más cercano a sus ideas": "Partido_cercano",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]": "Intencion_voto",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]": "Intencion_voto_alternativo",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]": "Simpatia",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales": "Voto_simpatia",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]": "Recuerdo_voto_2023",

    "PESPANNA1 Primer problema": "Problema_1",
    "PESPANNA2 Segundo problema": "Problema_2",
    "PESPANNA3 Tercer problema": "Problema_3"
})

# %%
df_marzo_25["Mes/Año"] = "03/2025"

# %%
print(df_marzo_25.head())
print(df_marzo_25.columns.tolist())
# Out:
#    Mes/Año     Id       CCAA           Poblacion_municipio    Sexo  Edad  \
# 0  03/2025  28203  Andalucía    10.001 a 50.000 habitantes  Hombre    45
# 1  03/2025  63387  Andalucía    10.001 a 50.000 habitantes   Mujer    60
# 2  03/2025  74875  Andalucía    10.001 a 50.000 habitantes  Hombre    60
# 3  03/2025  10108  Andalucía    10.001 a 50.000 habitantes  Hombre    43
# 4  03/2025   3233  Andalucía  100.001 a 400.000 habitantes   Mujer    38
#
#      Ideologia               Religiosidad    Practica_religion  \
# 0            5   Indiferente, no creyente                 N.P.
# 1  1 Izquierda  Católico/a no practicante                Nunca
# 2            3  Católico/a no practicante           Casi nunca
# 3            4  Católico/a no practicante  Varias veces al año
# 4   10 Derecha  Católico/a no practicante  Varias veces al año
#
#               Estudios  ... Participacion_2023 Partido_cercano  \
# 0             Primaria  ...            No votó         Ninguno
# ...

# %%
for col in df_marzo_25.columns:
    print(f"\n--- {col} ---")
    print(df_marzo_25[col].value_counts(dropna=False).head(20))
# Out:
# --- Mes/Año ---
# Mes/Año
# 03/2025    4018
# Name: count, dtype: int64
#
# --- Id ---
# Id
# 160741    1
# 28203     1
# 28933     1
# 28220     1
# 20602     1
# 16928     1
# 10176     1
# 153035    1
# 143513    1
# 134470    1
# 121924    1
# 116034    1
# 97982     1
# 97552     1
# 96581     1
# 93448     1
# 91372     1
# 89816     1
# 68363     1
# 62637     1
# Name: count, dtype: int64
#
# --- CCAA ---
# CCAA
# Andalucía                       679
# Madrid (Comunidad de)           562
# Cataluña                        555
# Comunitat Valenciana            412
# Galicia                         247
# Castilla y León                 196
# Castilla-La Mancha              174
# País Vasco                      169
# Canarias                        154
# Murcia (Región de)              118
# Balears (Illes)                 115
# Extremadura                     113
# Navarra (Comunidad Foral de)    105
# Cantabria                       103
# Aragón                           95
# ...

# %%
import pandas as pd

df_abril_25 = pd.read_csv("abril_2025.csv", sep=";", encoding="utf-8")

# %%
columnas_keep = [
    "ESTUDIO Código del estudio",
    "REGISTRO Número de registro",
    "CCAA Comunidad autónoma",
    "TAMUNI Tamaño de municipio",
    "SEXO Sexo de la persona entrevistada",
    "EDAD Edad de la persona entrevistada",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)",
    "RELIGION Religiosidad de la persona entrevistada",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos",
    "ESTUDIOS Estudios de la persona entrevistada",
    "SITLAB Situación laboral de la persona entrevistada",
    "INGRESHOG Nivel de ingresos netos del hogar",
    "CLASESUB Identificación subjetiva de clase",
    "IA_E1_MES Mes de realización",
    "IA_E1_ANYO Año de realización",
    "PESO Ponderación con ajuste por Estudios",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023",
    "CERCANIA Partido político que considera más cercano a sus ideas",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales [recodificada]",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]",

    "PESPANNA1 Primer problema",
    "PESPANNA2 Segundo problema",
    "PESPANNA3 Tercer problema"
]

df_abril_25 = df_abril_25[columnas_keep].copy()

# %%
# Renombrar columnas a nombres más cómodos
df_abril_25 = df_abril_25.rename(columns={
    "ESTUDIO Código del estudio": "Mes/Año",
    "REGISTRO Número de registro": "Id",
    "CCAA Comunidad autónoma": "CCAA",
    "TAMUNI Tamaño de municipio": "Poblacion_municipio",
    "SEXO Sexo de la persona entrevistada": "Sexo",
    "EDAD Edad de la persona entrevistada": "Edad",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)": "Ideologia",
    "RELIGION Religiosidad de la persona entrevistada": "Religiosidad",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos": "Practica_religion",
    "ESTUDIOS Estudios de la persona entrevistada": "Estudios",
    "SITLAB Situación laboral de la persona entrevistada": "Situacion_laboral",
    "INGRESHOG Nivel de ingresos netos del hogar": "Ingresos_hogar",
    "CLASESUB Identificación subjetiva de clase": "Clase_social",
    "IA_E1_MES Mes de realización": "Mes",
    "IA_E1_ANYO Año de realización": "Año",
    "PESO Ponderación con ajuste por Estudios": "Peso",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023": "Participacion_2023",
    "CERCANIA Partido político que considera más cercano a sus ideas": "Partido_cercano",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]": "Intencion_voto",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]": "Intencion_voto_alternativo",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]": "Simpatia",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales [recodificada]": "Voto_simpatia",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]": "Recuerdo_voto_2023",

    "PESPANNA1 Primer problema": "Problema_1",
    "PESPANNA2 Segundo problema": "Problema_2",
    "PESPANNA3 Tercer problema": "Problema_3"
})

# %%
df_abril_25["Mes/Año"] = "04/2025"

# %%
print(df_abril_25.head())
print(df_abril_25.columns.tolist())
# Out:
#    Mes/Año   Id                   CCAA             Poblacion_municipio  \
# 0  04/2025  178  Madrid (Comunidad de)     Más de 1.000.000 habitantes
# 1  04/2025  218                 Aragón  400.001 a 1.000.000 habitantes
# 2  04/2025  251               Cataluña     50.001 a 100.000 habitantes
# 3  04/2025  281  Madrid (Comunidad de)     Más de 1.000.000 habitantes
# 4  04/2025  326  Madrid (Comunidad de)     Más de 1.000.000 habitantes
#
#      Sexo  Edad   Ideologia  \
# 0   Mujer    64           4
# 1  Hombre    39           5
# 2   Mujer    53           4
# 3   Mujer    41           3
# 4  Hombre    62  10 Derecha
#
#                                         Religiosidad Practica_religion  \
# 0                          Católico/a no practicante        Casi nunca
# 1  Agnóstico/a (no niegan la existencia de Dios p...              N.P.
# 2                           Indiferente, no creyente              N.P.
# 3             Ateo/a (niegan la existencia de Dios)               N.P.
# ...

# %%
for col in df_abril_25.columns:
    print(f"\n--- {col} ---")
    print(df_abril_25[col].value_counts(dropna=False).head(20))
# Out:
# --- Mes/Año ---
# Mes/Año
# 04/2025    4008
# Name: count, dtype: int64
#
# --- Id ---
# Id
# 218129    1
# 178       1
# 218       1
# 251       1
# 281       1
# 326       1
# 341       1
# 390       1
# 217201    1
# 217148    1
# 217075    1
# 217027    1
# 217004    1
# 216973    1
# 216935    1
# 216892    1
# 216780    1
# 216720    1
# 216715    1
# 216708    1
# Name: count, dtype: int64
#
# --- CCAA ---
# CCAA
# Andalucía                       671
# Cataluña                        573
# Madrid (Comunidad de)           543
# Comunitat Valenciana            407
# Galicia                         237
# Castilla y León                 202
# País Vasco                      178
# Canarias                        171
# Castilla-La Mancha              162
# Murcia (Región de)              117
# Cantabria                       109
# Extremadura                     108
# Navarra (Comunidad Foral de)    108
# Balears (Illes)                 102
# Aragón                           98
# ...

# %%
import pandas as pd

df_mayo_25 = pd.read_csv("mayo_2025.csv", sep=";", encoding="utf-8")

# %%
columnas_keep = [
    "ESTUDIO Código del estudio",
    "REGISTRO Número de registro",
    "CCAA Comunidad autónoma",
    "TAMUNI Tamaño de municipio",
    "SEXO Sexo de la persona entrevistada",
    "EDAD Edad de la persona entrevistada",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)",
    "RELIGION Religiosidad de la persona entrevistada",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos",
    "ESTUDIOS Estudios de la persona entrevistada",
    "SITLAB Situación laboral de la persona entrevistada",
    "INGRESHOG Nivel de ingresos netos del hogar",
    "CLASESUB Identificación subjetiva de clase",
    "IA_E1_MES Mes de realización",
    "IA_E1_ANYO Año de realización",
    "PESO Ponderación con ajuste por Estudios",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023",
    "CERCANIA Partido político que considera más cercano a sus ideas",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales [recodificada]",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]",

    "PESPANNA1 Primer problema",
    "PESPANNA2 Segundo problema",
    "PESPANNA3 Tercer problema"
]

df_mayo_25 = df_mayo_25[columnas_keep].copy()

# %%
# Renombrar columnas a nombres más cómodos
df_mayo_25 = df_mayo_25.rename(columns={
    "ESTUDIO Código del estudio": "Mes/Año",
    "REGISTRO Número de registro": "Id",
    "CCAA Comunidad autónoma": "CCAA",
    "TAMUNI Tamaño de municipio": "Poblacion_municipio",
    "SEXO Sexo de la persona entrevistada": "Sexo",
    "EDAD Edad de la persona entrevistada": "Edad",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)": "Ideologia",
    "RELIGION Religiosidad de la persona entrevistada": "Religiosidad",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos": "Practica_religion",
    "ESTUDIOS Estudios de la persona entrevistada": "Estudios",
    "SITLAB Situación laboral de la persona entrevistada": "Situacion_laboral",
    "INGRESHOG Nivel de ingresos netos del hogar": "Ingresos_hogar",
    "CLASESUB Identificación subjetiva de clase": "Clase_social",
    "IA_E1_MES Mes de realización": "Mes",
    "IA_E1_ANYO Año de realización": "Año",
    "PESO Ponderación con ajuste por Estudios": "Peso",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023": "Participacion_2023",
    "CERCANIA Partido político que considera más cercano a sus ideas": "Partido_cercano",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]": "Intencion_voto",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]": "Intencion_voto_alternativo",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]": "Simpatia",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales [recodificada]": "Voto_simpatia",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]": "Recuerdo_voto_2023",

    "PESPANNA1 Primer problema": "Problema_1",
    "PESPANNA2 Segundo problema": "Problema_2",
    "PESPANNA3 Tercer problema": "Problema_3"
})

# %%
df_mayo_25["Mes/Año"] = "05/2025"

# %%
print(df_mayo_25.head())
print(df_mayo_25.columns.tolist())
# Out:
#    Mes/Año   Id                  CCAA             Poblacion_municipio    Sexo  \
# 0  05/2025  141               Galicia      10.001 a 50.000 habitantes   Mujer
# 1  05/2025  179  Comunitat Valenciana     50.001 a 100.000 habitantes  Hombre
# 2  05/2025  184               Galicia    100.001 a 400.000 habitantes  Hombre
# 3  05/2025  203             Andalucía      10.001 a 50.000 habitantes  Hombre
# 4  05/2025  208             Andalucía  400.001 a 1.000.000 habitantes   Mujer
#
#    Edad   Ideologia                                       Religiosidad  \
# 0    62  10 Derecha                          Católico/a no practicante
# 1    66           5                          Católico/a no practicante
# 2    46           3                             Católico/a practicante
# 3    66           4  Agnóstico/a (no niegan la existencia de Dios p...
# 4    56           5             Ateo/a (niegan la existencia de Dios)
#
# ...

# %%
import pandas as pd

df_junio_25 = pd.read_csv("junio_2025.csv", sep=";", encoding="utf-8")

# %%
columnas_keep = [
    "ESTUDIO Código del estudio",
    "REGISTRO Número de registro",
    "CCAA Comunidad autónoma",
    "TAMUNI Tamaño de municipio",
    "SEXO Sexo de la persona entrevistada",
    "EDAD Edad de la persona entrevistada",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)",
    "RELIGION Religiosidad de la persona entrevistada",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos",
    "ESTUDIOS Estudios de la persona entrevistada",
    "SITLAB Situación laboral de la persona entrevistada",
    "INGRESHOG Nivel de ingresos netos del hogar",
    "CLASESUB Identificación subjetiva de clase",
    "IA_E1_MES Mes de realización",
    "IA_E1_ANYO Año de realización",
    "PESO Ponderación con ajuste por Estudios",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023",
    "CERCANIA Partido político que considera más cercano a sus ideas",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]",

    "PESPANNA1 Primer problema",
    "PESPANNA2 Segundo problema",
    "PESPANNA3 Tercer problema"
]

df_junio_25 = df_junio_25[columnas_keep].copy()

# %%
# Renombrar columnas a nombres más cómodos
df_junio_25 = df_junio_25.rename(columns={
    "ESTUDIO Código del estudio": "Mes/Año",
    "REGISTRO Número de registro": "Id",
    "CCAA Comunidad autónoma": "CCAA",
    "TAMUNI Tamaño de municipio": "Poblacion_municipio",
    "SEXO Sexo de la persona entrevistada": "Sexo",
    "EDAD Edad de la persona entrevistada": "Edad",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)": "Ideologia",
    "RELIGION Religiosidad de la persona entrevistada": "Religiosidad",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos": "Practica_religion",
    "ESTUDIOS Estudios de la persona entrevistada": "Estudios",
    "SITLAB Situación laboral de la persona entrevistada": "Situacion_laboral",
    "INGRESHOG Nivel de ingresos netos del hogar": "Ingresos_hogar",
    "CLASESUB Identificación subjetiva de clase": "Clase_social",
    "IA_E1_MES Mes de realización": "Mes",
    "IA_E1_ANYO Año de realización": "Año",
    "PESO Ponderación con ajuste por Estudios": "Peso",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023": "Participacion_2023",
    "CERCANIA Partido político que considera más cercano a sus ideas": "Partido_cercano",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]": "Intencion_voto",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]": "Intencion_voto_alternativo",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]": "Simpatia",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales": "Voto_simpatia",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]": "Recuerdo_voto_2023",

    "PESPANNA1 Primer problema": "Problema_1",
    "PESPANNA2 Segundo problema": "Problema_2",
    "PESPANNA3 Tercer problema": "Problema_3"
})

# %%
df_junio_25["Mes/Año"] = "06/2025"

# %%
print(df_junio_25.head())
print(df_junio_25.columns.tolist())
# Out:
#    Mes/Año      Id       CCAA           Poblacion_municipio    Sexo  Edad  \
# 0  06/2025   76085  Andalucía    10.001 a 50.000 habitantes  Hombre    55
# 1  06/2025  174691  Andalucía     2.001 a 10.000 habitantes  Hombre    50
# 2  06/2025    6297  Andalucía  100.001 a 400.000 habitantes  Hombre    72
# 3  06/2025   10452  Andalucía  100.001 a 400.000 habitantes   Mujer    42
# 4  06/2025   10707  Andalucía  100.001 a 400.000 habitantes   Mujer    22
#
#   Ideologia                                       Religiosidad  \
# 0         5                           Indiferente, no creyente
# 1         3                          Católico/a no practicante
# 2         5                          Católico/a no practicante
# 3         5             Ateo/a (niegan la existencia de Dios)
# 4         4  Agnóstico/a (no niegan la existencia de Dios p...
#
#   Practica_religion             Estudios  ... Participacion_2023  \
# 0              N.P.                 F.P.  ...               Votó
# ...

# %%
import pandas as pd

df_julio_25 = pd.read_csv("julio_2025.csv", sep=";", encoding="utf-8")

# %%
columnas_keep = [
    "ESTUDIO Código del estudio",
    "REGISTRO Número de registro",
    "CCAA Comunidad autónoma",
    "TAMUNI Tamaño de municipio",
    "SEXO Sexo de la persona entrevistada",
    "EDAD Edad de la persona entrevistada",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)",
    "RELIGION Religiosidad de la persona entrevistada",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos",
    "ESTUDIOS Estudios de la persona entrevistada",
    "SITLAB Situación laboral de la persona entrevistada",
    "INGRESHOG Nivel de ingresos netos del hogar",
    "CLASESUB Identificación subjetiva de clase",
    "IA_E1_MES Mes de realización",
    "IA_E1_ANYO Año de realización",
    "PESO Ponderación con ajuste por Estudios",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023",
    "CERCANIA Partido político que considera más cercano a sus ideas",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales [recodificada]",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]",

    "PESPANNA1 Primer problema",
    "PESPANNA2 Segundo problema",
    "PESPANNA3 Tercer problema"
]

df_julio_25 = df_julio_25[columnas_keep].copy()

# %%
# Renombrar columnas a nombres más cómodos
df_julio_25 = df_julio_25.rename(columns={
    "ESTUDIO Código del estudio": "Mes/Año",
    "REGISTRO Número de registro": "Id",
    "CCAA Comunidad autónoma": "CCAA",
    "TAMUNI Tamaño de municipio": "Poblacion_municipio",
    "SEXO Sexo de la persona entrevistada": "Sexo",
    "EDAD Edad de la persona entrevistada": "Edad",
    "ESCIDEOL Escala de autoubicación ideológica (1-10)": "Ideologia",
    "RELIGION Religiosidad de la persona entrevistada": "Religiosidad",
    "PRACTICARELIG6 Frecuencia de asistencia a oficios religiosos": "Practica_religion",
    "ESTUDIOS Estudios de la persona entrevistada": "Estudios",
    "SITLAB Situación laboral de la persona entrevistada": "Situacion_laboral",
    "INGRESHOG Nivel de ingresos netos del hogar": "Ingresos_hogar",
    "CLASESUB Identificación subjetiva de clase": "Clase_social",
    "IA_E1_MES Mes de realización": "Mes",
    "IA_E1_ANYO Año de realización": "Año",
    "PESO Ponderación con ajuste por Estudios": "Peso",

    "PARTICIPACIONG Participación electoral en las elecciones generales de 2023": "Participacion_2023",
    "CERCANIA Partido político que considera más cercano a sus ideas": "Partido_cercano",
    "INTENCIONGR Intención de voto en unas supuestas elecciones generales [recodificada]": "Intencion_voto",
    "INTENCIONGALTERR Intención de voto alternativo en supuestas elecciones generales [recodificada]": "Intencion_voto_alternativo",
    "SIMPATIAR Partido político por el que se siente más simpatía en las elecciones generales (con filtro) [recodificada]": "Simpatia",
    "VOTOSIMG Voto+simpatía en supuestas elecciones generales [recodificada]": "Voto_simpatia",
    "RECUVOTOGR Recuerdo de voto en las elecciones generales de 2023 de los votantes [recodificada]": "Recuerdo_voto_2023",

    "PESPANNA1 Primer problema": "Problema_1",
    "PESPANNA2 Segundo problema": "Problema_2",
    "PESPANNA3 Tercer problema": "Problema_3"
})

# %%
df_julio_25["Mes/Año"] = "07/2025"

# %%
print(df_julio_25.head())
print(df_julio_25.columns.tolist())
# Out:
#    Mes/Año   Id                          CCAA           Poblacion_municipio  \
# 0  07/2025  132                     Andalucía  100.001 a 400.000 habitantes
# 1  07/2025  150                     Andalucía   50.001 a 100.000 habitantes
# 2  07/2025  167                     Andalucía   50.001 a 100.000 habitantes
# 3  07/2025  242                      Cataluña     2.001 a 10.000 habitantes
# 4  07/2025  281  Navarra (Comunidad Foral de)     2.001 a 10.000 habitantes
#
#      Sexo  Edad    Ideologia                            Religiosidad  \
# 0  Hombre    48            4  Ateo/a (niegan la existencia de Dios)
# 1   Mujer    61            7               Católico/a no practicante
# 2  Hombre    58            4  Ateo/a (niegan la existencia de Dios)
# 3  Hombre    66  1 Izquierda  Ateo/a (niegan la existencia de Dios)
# 4  Hombre    51   10 Derecha               Católico/a no practicante
#
#      Practica_religion             Estudios  ... Participacion_2023  \
# ...

# %%
df_marzo_25["Id_unico"] = "03/2025_" + df_marzo_25["Id"].astype(str)
df_abril_25["Id_unico"] = "04/2025_" + df_abril_25["Id"].astype(str)
df_mayo_25["Id_unico"] = "05/2025_" + df_mayo_25["Id"].astype(str)
df_junio_25["Id_unico"] = "06/2025_" + df_junio_25["Id"].astype(str)
df_julio_25["Id_unico"] = "07/2025_" + df_julio_25["Id"].astype(str)

# %%
df_total = pd.concat(
    [df_marzo_25, df_abril_25, df_mayo_25, df_junio_25, df_julio_25],
    ignore_index=True
)

# %%
print(df_total.shape)
print(df_total["Mes/Año"].value_counts())
# Out:
# (20075, 27)
# Mes/Año
# 03/2025    4018
# 05/2025    4018
# 07/2025    4018
# 06/2025    4013
# 04/2025    4008
# Name: count, dtype: int64

# %%
for col in df_total.columns:
    print(f"\n--- {col} ---")
    print(df_total[col].value_counts(dropna=False).head(20))
# Out:
# --- Mes/Año ---
# Mes/Año
# 03/2025    4018
# 05/2025    4018
# 07/2025    4018
# 06/2025    4013
# 04/2025    4008
# Name: count, dtype: int64
#
# --- Id ---
# Id
# 61718    3
# 25854    3
# 25306    3
# 51239    3
# 6579     3
# 41341    3
# 17950    3
# 21803    3
# 78896    3
# 50039    3
# 72480    3
# 46221    3
# 50373    3
# 21328    3
# 42641    3
# 1218     3
# 22024    3
# 35557    3
# 2734     3
# 26188    3
# Name: count, dtype: int64
#
# --- CCAA ---
# CCAA
# Andalucía                       3392
# Madrid (Comunidad de)           2836
# Cataluña                        2791
# Comunitat Valenciana            1983
# Galicia                         1203
# Castilla y León                 1010
# País Vasco                       874
# Castilla-La Mancha               855
# Canarias                         837
# Murcia (Región de)               611
# Balears (Illes)                  520
# Extremadura                      517
# Navarra (Comunidad Foral de)     516
# ...

# %%
df_total["Peso"] = (
    df_total["Peso"]
    .astype(str)
    .str.replace(",", ".", regex=False)
    .astype(float)
)

# %%
print(df_total["Peso"].describe())
print(df_total["Peso"].head())
print(df_total["Peso"].dtype)
# Out:
# count    20075.000000
# mean         1.000000
# std          1.050389
# min          0.079730
# 25%          0.446840
# 50%          0.605580
# 75%          1.026760
# max         11.675470
# Name: Peso, dtype: float64
# 0    4.28036
# 1    2.96258
# 2    0.49482
# 3    4.20117
# 4    3.50568
# Name: Peso, dtype: float64
# float64

# %%
import numpy as np

valores_missing = ["N.S.", "N.C.", "N.R."]

for col in df_total:
    df_total[col] = df_total[col].replace(valores_missing, np.nan)

# %%
for col in df_total.columns:
    print(f"\n--- {col} ---")
    print(df_total[col].value_counts(dropna=False).head(20))
# Out:
# --- Mes/Año ---
# Mes/Año
# 03/2025    4018
# 05/2025    4018
# 07/2025    4018
# 06/2025    4013
# 04/2025    4008
# Name: count, dtype: int64
#
# --- Id ---
# Id
# 61718    3
# 25854    3
# 25306    3
# 51239    3
# 6579     3
# 41341    3
# 17950    3
# 21803    3
# 78896    3
# 50039    3
# 72480    3
# 46221    3
# 50373    3
# 21328    3
# 42641    3
# 1218     3
# 22024    3
# 35557    3
# 2734     3
# 26188    3
# Name: count, dtype: int64
#
# --- CCAA ---
# CCAA
# Andalucía                       3392
# Madrid (Comunidad de)           2836
# Cataluña                        2791
# Comunitat Valenciana            1983
# Galicia                         1203
# Castilla y León                 1010
# País Vasco                       874
# Castilla-La Mancha               855
# Canarias                         837
# Murcia (Región de)               611
# Balears (Illes)                  520
# Extremadura                      517
# Navarra (Comunidad Foral de)     516
# ...

# %%
print(df_total["Ideologia"].value_counts(dropna=False))
print(df_total["Religiosidad"].value_counts(dropna=False))
print(df_total["Practica_religion"].value_counts(dropna=False))
# Out:
# Ideologia
# 5              4518
# 3              2847
# 1 Izquierda    2142
# 4              2104
# 6              1935
# 7              1742
# 2              1341
# 8              1281
# 10 Derecha     1113
# NaN             746
# 9               306
# Name: count, dtype: int64
# Religiosidad
# Católico/a no practicante                                                   7019
# Católico/a practicante                                                      3502
# Ateo/a (niegan la existencia de Dios)                                       3375
# Agnóstico/a (no niegan la existencia de Dios pero tampoco la descartan)     2846
# Indiferente, no creyente                                                    2490
# Creyente de otra religión                                                    561
# NaN                                                                          282
# Name: count, dtype: int64
# Practica_religion
# N.P.                             7318
# ...
